# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("C:/Users/DIPANSHI/Desktop/ab.csv")

# %%
df.head()
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
plt.plot(df["MaxTemp"],df["MinTemp"])      #plot 1
plt.ylabel("MinTemp")
plt.xlabel("MaxTemp")
plt.show()

# %%
plt.scatter(df["MaxTemp"],df["MinTemp"],c="b",marker="*")     #plot 2
plt.ylabel("MinTemp")
plt.xlabel("MaxTemp")
plt.show()

# %%
sns.distplot(df["MaxTemp"],kde=True)     #plot 3

# %%
sns.distplot(df["MaxTemp"],kde=False)     #plot 4

# %%
sns.kdeplot(df['MaxTemp'], color="b", shade=True)     #plot 5

# %%
sns.distplot(df['MinTemp'],kde=True, color="black", hist=False, rug=True)     #plot 6

# %%
sns.jointplot(df['MinTemp'],df['MaxTemp'],data=df)      #plot 7

# %%
sns.jointplot(df['MinTemp'],df['MaxTemp'],kind='hex', color='r')    #plot 8

# %%
sns.kdeplot(df['MinTemp'],df['MaxTemp'])    #plot 9

# %%
sns.kdeplot(df["MinTemp"],df["MaxTemp"],shade=True)      #plot 10

# %%
sns.jointplot(df['MinTemp'],df['MaxTemp'],kind='kde', color='green')     #plot 11

# %%
tips = sns.load_dataset('tips')     #plot 12
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.pairplot(tips)      #plot 13

# %%
plt.figure(figsize=(10,8))      #plot 14
sns.stripplot(x='MaxTemp',y='MinTemp',data=df)

# %%
plt.figure(figsize=(10,8))        #plot 15
sns.swarmplot(x='MaxTemp',y='MinTemp',data=df)

# %%
sns.boxplot(x='MaxTemp',y='MinTemp',data=df)        #plot 16

# %%
sns.barplot(x='MaxTemp',y='MinTemp',data=df , hue='Location')     #plot 17

# %%
sns.countplot(x='MaxTemp',data=df)     #plot 18

# %%
plt.figure(figsize=(10,8))    #plot 19
corr=df.corr()
sns.heatmap(corr)

# %%
t1 = np.arange(0.0, 5.0, 0.1)          #plot 20
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(1)
plt.subplot(211)# numrows, numcols, figure
plt.plot(t1, t1, 'bo',label='t1')
plt.plot(t2, t2**2, 'g',label='t2')
plt.title('Subplots')
plt.legend

plt.subplot(212)# numrows, numcols, figure
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.grid(True)
plt.text(2.18, 0.8, r'cos func')
plt.show()

# %%
sns.lmplot(x="MinTemp",y="MaxTemp",data=df,hue="Rainfall")      #plot 21
